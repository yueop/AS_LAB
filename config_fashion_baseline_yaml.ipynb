# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/config_fashion_baseline_yaml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
Project_Path = ('/content/drive/MyDrive/AS_LAB')
if not os.path.exists(Project_Path):
    os.makedirs(Project_Path)

os.chdir(Project_Path)
# Out:
# Mounted at /content/drive

# %%
FILE_NAME = 'config_fashion_baseline.yaml'
SAVE_PATH = f"/content/drive/MyDrive/AS_LAB/{FILE_NAME}"

# %%
config_text = """
project_name: "FASHION_MNIST_CNN"

data:
    dataset_name: "fashion_mnist"
    batch_size: 64
    num_workers: 0
    augmentation:
        use_aug: False
        rotation: 10
        flip_prob: 0.0

model:
    type: "cnn"
    input_size: 784
    hidden_size: 256
    num_classes: 10
    dropout_rate: 0.0

train:
    num_epochs: 50
    learning_rate: 0.001
    seed: 42
    save_path: "best_fashion_mnist_cnn.pth"

    patience: 5
    optimizer: "adam"
    weight_decay: 0.0

    use_scheduler: True
    scheduler_step: 10
    scheduler_gamma: 0.1
"""

with open(SAVE_PATH, 'w', encoding='utf-8') as f:
    f.write(config_text.strip())

print(f"설정 파일이 저장되었습니다.")
# Out:
# 설정 파일이 저장되었습니다.
