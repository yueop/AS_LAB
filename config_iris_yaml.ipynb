# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/config_iris_yaml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
# 파일 이름을 명시적으로 지정
FILE_NAME = "config_iris.yaml"
# 전체 경로 사용
SAVE_PATH = f"/content/drive/MyDrive/AS_LAB/{FILE_NAME}"

# %%
config_text = """
project_name: "IRIS_Project"
data:
  dataset_name: "iris"
  batch_size: 16
  num_workers: 0
  split_ratio: 0.25
  augmentation:
    use_aug: False
    rotation: 0
    flip_prob: 0.0

model:
  type: "mlp"
  input_size: 4
  hidden_size: 16
  num_classes: 3
  dropout_rate: 0.0

train:
  num_epochs: 100
  learning_rate: 0.01
  patience: 10
  seed: 42
  save_path: "best_iris.pth"
  optimizer: "adam"
  weight_decay: 0.0
  use_scheduler: False
"""
with open(SAVE_PATH, 'w', encoding='utf-8') as f:
    f.write(config_text.strip())
