# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/config_fashion_improved_yaml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
PROJECT_PATH = ('/content/drive/MyDrive/AS_LAB')
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

os.chdir(PROJECT_PATH)
# Out:
# Mounted at /content/drive

# %%
FILE_NAME = 'config_fashion_improved.yaml'
SAVE_PATH = f"/content/drive/MyDrive/AS_LAB/{FILE_NAME}"

# %%
config_text = """
project_name: 'FASHION_MNIST_IMPROVED_CNN'

data:
    dataset_name: "fashion_mnist"
    batch_size: 64
    num_workers: 0
    augmentation:
        use_aug: True
        rotation: 5
        flip_prob: 0.5

model:
    type: "deepcnn"
    input_size: 784
    hidden_size: 256
    num_classes: 10
    dropout_rate: 0.25

train:
    num_epochs: 60
    learning_rate: 0.001
    seed: 42
    save_path: "best_fashion_mnist_deepcnn.pth"

    patience: 10
    optimizer: "adam"
    weight_decay: 0.0

    use_scheduler: True
    scheduler_step: 20
    scheduler_gamma: 0.1
"""

with open(SAVE_PATH, 'w', encoding='utf-8') as f:
    f.write(config_text.strip())

print("저장 완료")
# Out:
# 저장 완료
