# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/iris_train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil
import subprocess
import sys

# 실시간 출력을 강제로 화면에 뿌려주는 헬퍼 함수
def run_live_output(command):
    # 프로세스 실행 (stdout을 파이프로 연결)
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,  # 에러 메시지도 같이 출력
        text=True,                 # 텍스트 모드로 읽기
        bufsize=1                  # 라인 버퍼링
    )

    # 프로세스가 뱉는 로그를 한 줄씩 실시간으로 print
    for line in process.stdout:
        print(line, end='')

    # 프로세스 종료 대기 및 에러 체크
    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

# --- 메인 실행 로직 ---

# 1. 설정 파일 복사
print("=== [1] IRIS 설정을 적용합니다... ===")
shutil.copy('config_iris.yaml', 'config.yaml')

# 2. train.py 실행
print("\n=== [2] IRIS 모델 학습 시작! ===")
run_live_output([sys.executable, "-u", "train.py"])

# 3. eval.py 실행
print("\n=== [3] IRIS 모델 평가 시작! ===")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# === [1] IRIS 설정을 적용합니다... ===
#
# === [2] IRIS 모델 학습 시작! ===
# device: cuda | model: mlp
# ---[디버깅] Seed 42 | 첫 번재 학습 데이터: [-1.47393679  1.20365799 -1.56253475 -1.31260282]---
# 학습을 시작합니다...
# Epoch [1/150] Time: 0.59s | Train Loss: 0.9924 Train Acc: 0.6583 | Val Loss: 0.7794 Val Acc: 0.9333
# Loss decreased (inf --> 0.779420). 모델을 저장합니다...
# Epoch [2/150] Time: 0.02s | Train Loss: 0.6839 Train Acc: 0.7500 | Val Loss: 0.3987 Val Acc: 0.8667
# Loss decreased (0.779420 --> 0.398731). 모델을 저장합니다...
# Epoch [3/150] Time: 0.01s | Train Loss: 0.4362 Train Acc: 0.8167 | Val Loss: 0.2513 Val Acc: 1.0000
# Loss decreased (0.398731 --> 0.251253). 모델을 저장합니다...
# Epoch [4/150] Time: 0.01s | Train Loss: 0.3184 Train Acc: 0.9000 | Val Loss: 0.1850 Val Acc: 1.0000
# Loss decreased (0.251253 --> 0.185035). 모델을 저장합니다...
# Epoch [5/150] Time: 0.01s | Train Loss: 0.2536 Train Acc: 0.8917 | Val Loss: 0.1114 Val Acc: 1.0000
# Loss decreased (0.185035 --> 0.111409). 모델을 저장합니다...
# Epoch [6/150] Time: 0.01s | Train Loss: 0.2031 Train Acc: 0.9167 | Val Loss: 0.0951 Val Acc: 1.0000
# Loss decreased (0.111409 --> 0.095076). 모델을 저장합니다...
# Epoch [7/150] Time: 0.02s | Train Loss: 0.1672 Train Acc: 0.9500 | Val Loss: 0.0733 Val Acc: 1.0000
# Loss decreased (0.095076 --> 0.073329). 모델을 저장합니다...
# Epoch [8/150] Time: 0.01s | Train Loss: 0.1219 Train Acc: 0.9583 | Val Loss: 0.0570 Val Acc: 1.0000
# Loss decreased (0.073329 --> 0.057047). 모델을 저장합니다...
# Epoch [9/150] Time: 0.01s | Train Loss: 0.1149 Train Acc: 0.9583 | Val Loss: 0.0610 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [10/150] Time: 0.02s | Train Loss: 0.1128 Train Acc: 0.9500 | Val Loss: 0.0357 Val Acc: 1.0000
# Loss decreased (0.057047 --> 0.035744). 모델을 저장합니다...
# Epoch [11/150] Time: 0.01s | Train Loss: 0.0822 Train Acc: 0.9667 | Val Loss: 0.0283 Val Acc: 1.0000
# Loss decreased (0.035744 --> 0.028323). 모델을 저장합니다...
# Epoch [12/150] Time: 0.02s | Train Loss: 0.0719 Train Acc: 0.9667 | Val Loss: 0.0345 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [13/150] Time: 0.01s | Train Loss: 0.0652 Train Acc: 0.9667 | Val Loss: 0.0232 Val Acc: 1.0000
# Loss decreased (0.028323 --> 0.023215). 모델을 저장합니다...
# Epoch [14/150] Time: 0.01s | Train Loss: 0.0649 Train Acc: 0.9667 | Val Loss: 0.0227 Val Acc: 1.0000
# Loss decreased (0.023215 --> 0.022684). 모델을 저장합니다...
# Epoch [15/150] Time: 0.01s | Train Loss: 0.0659 Train Acc: 0.9667 | Val Loss: 0.0273 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [16/150] Time: 0.01s | Train Loss: 0.0550 Train Acc: 0.9750 | Val Loss: 0.0194 Val Acc: 1.0000
# Loss decreased (0.022684 --> 0.019421). 모델을 저장합니다...
# Epoch [17/150] Time: 0.01s | Train Loss: 0.0671 Train Acc: 0.9667 | Val Loss: 0.0272 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [18/150] Time: 0.01s | Train Loss: 0.0604 Train Acc: 0.9667 | Val Loss: 0.0236 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [19/150] Time: 0.01s | Train Loss: 0.0501 Train Acc: 0.9833 | Val Loss: 0.0476 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [20/150] Time: 0.01s | Train Loss: 0.0603 Train Acc: 0.9667 | Val Loss: 0.0208 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [21/150] Time: 0.01s | Train Loss: 0.0780 Train Acc: 0.9583 | Val Loss: 0.0382 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 20
# Epoch [22/150] Time: 0.01s | Train Loss: 0.0941 Train Acc: 0.9667 | Val Loss: 0.0120 Val Acc: 1.0000
# Loss decreased (0.019421 --> 0.012017). 모델을 저장합니다...
# Epoch [23/150] Time: 0.01s | Train Loss: 0.0492 Train Acc: 0.9750 | Val Loss: 0.0532 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [24/150] Time: 0.01s | Train Loss: 0.0698 Train Acc: 0.9667 | Val Loss: 0.0181 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [25/150] Time: 0.02s | Train Loss: 0.0461 Train Acc: 0.9833 | Val Loss: 0.0338 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [26/150] Time: 0.01s | Train Loss: 0.0456 Train Acc: 0.9833 | Val Loss: 0.0261 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [27/150] Time: 0.01s | Train Loss: 0.0439 Train Acc: 0.9750 | Val Loss: 0.0305 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 20
# Epoch [28/150] Time: 0.01s | Train Loss: 0.0429 Train Acc: 0.9833 | Val Loss: 0.0228 Val Acc: 1.0000
# EarlyStopping counter: 6 out of 20
# Epoch [29/150] Time: 0.01s | Train Loss: 0.0523 Train Acc: 0.9750 | Val Loss: 0.0304 Val Acc: 1.0000
# EarlyStopping counter: 7 out of 20
# Epoch [30/150] Time: 0.02s | Train Loss: 0.0502 Train Acc: 0.9667 | Val Loss: 0.0158 Val Acc: 1.0000
# EarlyStopping counter: 8 out of 20
# Epoch [31/150] Time: 0.01s | Train Loss: 0.0393 Train Acc: 0.9833 | Val Loss: 0.0327 Val Acc: 1.0000
# EarlyStopping counter: 9 out of 20
# Epoch [32/150] Time: 0.01s | Train Loss: 0.0494 Train Acc: 0.9833 | Val Loss: 0.0178 Val Acc: 1.0000
# EarlyStopping counter: 10 out of 20
# Epoch [33/150] Time: 0.01s | Train Loss: 0.0369 Train Acc: 0.9833 | Val Loss: 0.0352 Val Acc: 1.0000
# EarlyStopping counter: 11 out of 20
# Epoch [34/150] Time: 0.01s | Train Loss: 0.0379 Train Acc: 0.9833 | Val Loss: 0.0316 Val Acc: 1.0000
# EarlyStopping counter: 12 out of 20
# Epoch [35/150] Time: 0.01s | Train Loss: 0.0569 Train Acc: 0.9833 | Val Loss: 0.0208 Val Acc: 1.0000
# EarlyStopping counter: 13 out of 20
# Epoch [36/150] Time: 0.01s | Train Loss: 0.0348 Train Acc: 0.9917 | Val Loss: 0.0468 Val Acc: 1.0000
# EarlyStopping counter: 14 out of 20
# Epoch [37/150] Time: 0.01s | Train Loss: 0.0678 Train Acc: 0.9750 | Val Loss: 0.0106 Val Acc: 1.0000
# Loss decreased (0.012017 --> 0.010579). 모델을 저장합니다...
# Epoch [38/150] Time: 0.01s | Train Loss: 0.0441 Train Acc: 0.9833 | Val Loss: 0.0413 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [39/150] Time: 0.02s | Train Loss: 0.0459 Train Acc: 0.9833 | Val Loss: 0.0164 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [40/150] Time: 0.01s | Train Loss: 0.0887 Train Acc: 0.9750 | Val Loss: 0.0094 Val Acc: 1.0000
# Loss decreased (0.010579 --> 0.009393). 모델을 저장합니다...
# Epoch [41/150] Time: 0.01s | Train Loss: 0.1009 Train Acc: 0.9667 | Val Loss: 0.0969 Val Acc: 0.9333
# EarlyStopping counter: 1 out of 20
# Epoch [42/150] Time: 0.01s | Train Loss: 0.0504 Train Acc: 0.9750 | Val Loss: 0.0107 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [43/150] Time: 0.01s | Train Loss: 0.0557 Train Acc: 0.9667 | Val Loss: 0.0490 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [44/150] Time: 0.01s | Train Loss: 0.0396 Train Acc: 0.9833 | Val Loss: 0.0313 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [45/150] Time: 0.01s | Train Loss: 0.0334 Train Acc: 0.9917 | Val Loss: 0.0238 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 20
# Epoch [46/150] Time: 0.01s | Train Loss: 0.0364 Train Acc: 0.9917 | Val Loss: 0.0311 Val Acc: 1.0000
# EarlyStopping counter: 6 out of 20
# Epoch [47/150] Time: 0.01s | Train Loss: 0.0367 Train Acc: 0.9833 | Val Loss: 0.0284 Val Acc: 1.0000
# EarlyStopping counter: 7 out of 20
# Epoch [48/150] Time: 0.01s | Train Loss: 0.0293 Train Acc: 0.9833 | Val Loss: 0.0156 Val Acc: 1.0000
# EarlyStopping counter: 8 out of 20
# Epoch [49/150] Time: 0.01s | Train Loss: 0.0528 Train Acc: 0.9750 | Val Loss: 0.0149 Val Acc: 1.0000
# EarlyStopping counter: 9 out of 20
# Epoch [50/150] Time: 0.01s | Train Loss: 0.0626 Train Acc: 0.9750 | Val Loss: 0.0856 Val Acc: 1.0000
# EarlyStopping counter: 10 out of 20
# Epoch [51/150] Time: 0.01s | Train Loss: 0.0348 Train Acc: 0.9833 | Val Loss: 0.0086 Val Acc: 1.0000
# Loss decreased (0.009393 --> 0.008585). 모델을 저장합니다...
# Epoch [52/150] Time: 0.02s | Train Loss: 0.0492 Train Acc: 0.9750 | Val Loss: 0.0113 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [53/150] Time: 0.02s | Train Loss: 0.0402 Train Acc: 0.9833 | Val Loss: 0.0349 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [54/150] Time: 0.02s | Train Loss: 0.0386 Train Acc: 0.9833 | Val Loss: 0.0107 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [55/150] Time: 0.01s | Train Loss: 0.0329 Train Acc: 0.9917 | Val Loss: 0.0157 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [56/150] Time: 0.04s | Train Loss: 0.0344 Train Acc: 0.9750 | Val Loss: 0.0295 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 20
# Epoch [57/150] Time: 0.05s | Train Loss: 0.0384 Train Acc: 0.9833 | Val Loss: 0.0113 Val Acc: 1.0000
# EarlyStopping counter: 6 out of 20
# Epoch [58/150] Time: 0.02s | Train Loss: 0.0428 Train Acc: 0.9917 | Val Loss: 0.0219 Val Acc: 1.0000
# EarlyStopping counter: 7 out of 20
# Epoch [59/150] Time: 0.01s | Train Loss: 0.0399 Train Acc: 0.9667 | Val Loss: 0.0601 Val Acc: 1.0000
# EarlyStopping counter: 8 out of 20
# Epoch [60/150] Time: 0.01s | Train Loss: 0.0425 Train Acc: 0.9750 | Val Loss: 0.0104 Val Acc: 1.0000
# EarlyStopping counter: 9 out of 20
# Epoch [61/150] Time: 0.02s | Train Loss: 0.0554 Train Acc: 0.9833 | Val Loss: 0.0502 Val Acc: 1.0000
# EarlyStopping counter: 10 out of 20
# Epoch [62/150] Time: 0.01s | Train Loss: 0.0335 Train Acc: 0.9833 | Val Loss: 0.0128 Val Acc: 1.0000
# EarlyStopping counter: 11 out of 20
# Epoch [63/150] Time: 0.01s | Train Loss: 0.0339 Train Acc: 0.9917 | Val Loss: 0.0338 Val Acc: 1.0000
# EarlyStopping counter: 12 out of 20
# Epoch [64/150] Time: 0.01s | Train Loss: 0.0301 Train Acc: 0.9833 | Val Loss: 0.0302 Val Acc: 1.0000
# EarlyStopping counter: 13 out of 20
# Epoch [65/150] Time: 0.01s | Train Loss: 0.0319 Train Acc: 0.9917 | Val Loss: 0.0186 Val Acc: 1.0000
# EarlyStopping counter: 14 out of 20
# Epoch [66/150] Time: 0.01s | Train Loss: 0.0255 Train Acc: 0.9917 | Val Loss: 0.0229 Val Acc: 1.0000
# EarlyStopping counter: 15 out of 20
# Epoch [67/150] Time: 0.01s | Train Loss: 0.0291 Train Acc: 0.9917 | Val Loss: 0.0240 Val Acc: 1.0000
# EarlyStopping counter: 16 out of 20
# Epoch [68/150] Time: 0.01s | Train Loss: 0.0323 Train Acc: 0.9833 | Val Loss: 0.0468 Val Acc: 1.0000
# EarlyStopping counter: 17 out of 20
# Epoch [69/150] Time: 0.01s | Train Loss: 0.0344 Train Acc: 0.9833 | Val Loss: 0.0072 Val Acc: 1.0000
# Loss decreased (0.008585 --> 0.007220). 모델을 저장합니다...
# Epoch [70/150] Time: 0.01s | Train Loss: 0.0293 Train Acc: 0.9917 | Val Loss: 0.0195 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [71/150] Time: 0.01s | Train Loss: 0.0309 Train Acc: 0.9833 | Val Loss: 0.0268 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [72/150] Time: 0.01s | Train Loss: 0.0200 Train Acc: 0.9917 | Val Loss: 0.0155 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [73/150] Time: 0.01s | Train Loss: 0.0513 Train Acc: 0.9833 | Val Loss: 0.0174 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [74/150] Time: 0.01s | Train Loss: 0.0396 Train Acc: 0.9833 | Val Loss: 0.0617 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 20
# Epoch [75/150] Time: 0.01s | Train Loss: 0.0355 Train Acc: 0.9917 | Val Loss: 0.0043 Val Acc: 1.0000
# Loss decreased (0.007220 --> 0.004328). 모델을 저장합니다...
# Epoch [76/150] Time: 0.01s | Train Loss: 0.0332 Train Acc: 0.9917 | Val Loss: 0.0070 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 20
# Epoch [77/150] Time: 0.01s | Train Loss: 0.0274 Train Acc: 0.9833 | Val Loss: 0.0359 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 20
# Epoch [78/150] Time: 0.01s | Train Loss: 0.0314 Train Acc: 0.9833 | Val Loss: 0.0114 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 20
# Epoch [79/150] Time: 0.01s | Train Loss: 0.0751 Train Acc: 0.9833 | Val Loss: 0.0078 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 20
# Epoch [80/150] Time: 0.01s | Train Loss: 0.0300 Train Acc: 0.9833 | Val Loss: 0.0814 Val Acc: 0.9333
# EarlyStopping counter: 5 out of 20
# Epoch [81/150] Time: 0.01s | Train Loss: 0.0308 Train Acc: 0.9833 | Val Loss: 0.0087 Val Acc: 1.0000
# EarlyStopping counter: 6 out of 20
# Epoch [82/150] Time: 0.01s | Train Loss: 0.0245 Train Acc: 0.9917 | Val Loss: 0.0104 Val Acc: 1.0000
# EarlyStopping counter: 7 out of 20
# Epoch [83/150] Time: 0.01s | Train Loss: 0.0238 Train Acc: 0.9917 | Val Loss: 0.0268 Val Acc: 1.0000
# EarlyStopping counter: 8 out of 20
# Epoch [84/150] Time: 0.02s | Train Loss: 0.0226 Train Acc: 0.9917 | Val Loss: 0.0161 Val Acc: 1.0000
# EarlyStopping counter: 9 out of 20
# Epoch [85/150] Time: 0.02s | Train Loss: 0.0203 Train Acc: 0.9917 | Val Loss: 0.0188 Val Acc: 1.0000
# EarlyStopping counter: 10 out of 20
# Epoch [86/150] Time: 0.01s | Train Loss: 0.0200 Train Acc: 0.9917 | Val Loss: 0.0224 Val Acc: 1.0000
# EarlyStopping counter: 11 out of 20
# Epoch [87/150] Time: 0.01s | Train Loss: 0.0204 Train Acc: 0.9833 | Val Loss: 0.0112 Val Acc: 1.0000
# EarlyStopping counter: 12 out of 20
# Epoch [88/150] Time: 0.01s | Train Loss: 0.0186 Train Acc: 0.9917 | Val Loss: 0.0097 Val Acc: 1.0000
# EarlyStopping counter: 13 out of 20
# Epoch [89/150] Time: 0.01s | Train Loss: 0.0240 Train Acc: 0.9917 | Val Loss: 0.0157 Val Acc: 1.0000
# EarlyStopping counter: 14 out of 20
# Epoch [90/150] Time: 0.01s | Train Loss: 0.0161 Train Acc: 0.9917 | Val Loss: 0.0110 Val Acc: 1.0000
# EarlyStopping counter: 15 out of 20
# Epoch [91/150] Time: 0.01s | Train Loss: 0.0270 Train Acc: 0.9917 | Val Loss: 0.0201 Val Acc: 1.0000
# EarlyStopping counter: 16 out of 20
# Epoch [92/150] Time: 0.01s | Train Loss: 0.0173 Train Acc: 0.9917 | Val Loss: 0.0139 Val Acc: 1.0000
# EarlyStopping counter: 17 out of 20
# Epoch [93/150] Time: 0.02s | Train Loss: 0.0170 Train Acc: 0.9917 | Val Loss: 0.0133 Val Acc: 1.0000
# EarlyStopping counter: 18 out of 20
# Epoch [94/150] Time: 0.01s | Train Loss: 0.0184 Train Acc: 0.9917 | Val Loss: 0.0133 Val Acc: 1.0000
# EarlyStopping counter: 19 out of 20
# Epoch [95/150] Time: 0.02s | Train Loss: 0.0134 Train Acc: 0.9917 | Val Loss: 0.0349 Val Acc: 1.0000
# EarlyStopping counter: 20 out of 20
# Early Stopping이 작동되었습니다.
# 학습이 종료되었습니다.
# 학습 그래프가 저장되었습니다: results/learning_curve.png
#
# === [3] IRIS 모델 평가 시작! ===
# 평가 시작. Project: IRIS_Project
# 모델 가중치 로드 성공: best_iris.pth
# 최종 테스트 정확도: 100.00%
# Confusion Matrix 저장 완료: results/confusion_matrix.png
