# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/config_yaml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')   #구글 드라이브 연결
Project_Path = '/content/drive/MyDrive/Colab Notebooks'  #저장할 폴더 경로 설정

#저장할 폴더 존재 여부 확인(없으면 새 폴더 생성, 있으면 기존 폴더 사용)
if not os.path.exists(Project_Path):
    os.makedirs(Project_Path)
    print(f"새 폴더 생성 후 저장 완료: {Project_Path}")
else:
    print(f"기존 폴더에 저장: {Project_Path}")

os.chdir(Project_Path)   #작업 위치 이동(change directory)

# %%
# %%writefile cinfig.yaml
# project_name: "IRIS_MLP_Project"
#
# data:
#     dataset_name: "iris" #데이터 셋 설정
#     batch_size: 16 #배치 사이즈 설정
#
# model:
#     type: "mlp" #모델 선택
#     input_size: 4 #입력 사이즈 설정
#     hidden_size: 16 #은닉층 사이즈 설정
#     num_classes: 3 #클래스 수 설정
#
# train:
#     num_epochs: 50 #반복할 세대 수 설정
#     learning_rate: 0.01 #학습률 설정
#     patience: 10 #early stopping 기다리는 횟수 지정
#     seed: 42 #시드 고정
#     save_path: "best_model.pth" #최고 성능 모델 저장 경로 지정
