# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/fashion_improved_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

os.chdir(PROJECT_PATH)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil
import subprocess
import sys
import os

def run_live_output(command):
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1
    )

    for line in process.stdout:
        print(line, end='')

    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

print("FASHION_IMPROVED 설정 적용")
shutil.copy('config_fashion_improved.yaml', 'config.yaml')

print("학습 시작")
run_live_output([sys.executable, "-u", "train.py"])

print("평가 시작")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# FASHION_IMPROVED 설정 적용
# 학습 시작
# device: cuda | model: deepcnn
# Scheduler Activated: StepLR (step=20, gamma=0.1)
# 학습을 시작합니다...
# Epoch [1/60] Time: 21.92s | Train Loss: 0.6061 Train Acc: 0.7895 | Val Loss: 0.3932 Val Acc: 0.8568
# Loss decreased (inf --> 0.393201). 모델을 저장합니다...
# Epoch [2/60] Time: 21.61s | Train Loss: 0.4178 Train Acc: 0.8482 | Val Loss: 0.3359 Val Acc: 0.8744
# Loss decreased (0.393201 --> 0.335895). 모델을 저장합니다...
# Epoch [3/60] Time: 20.74s | Train Loss: 0.3822 Train Acc: 0.8613 | Val Loss: 0.3235 Val Acc: 0.8789
# Loss decreased (0.335895 --> 0.323492). 모델을 저장합니다...
# Epoch [4/60] Time: 21.54s | Train Loss: 0.3640 Train Acc: 0.8688 | Val Loss: 0.3099 Val Acc: 0.8840
# Loss decreased (0.323492 --> 0.309897). 모델을 저장합니다...
# Epoch [5/60] Time: 21.32s | Train Loss: 0.3505 Train Acc: 0.8723 | Val Loss: 0.3033 Val Acc: 0.8912
# Loss decreased (0.309897 --> 0.303273). 모델을 저장합니다...
# ...

# %%
import torch

# 1. 파이토치 버전 확인
print(f"PyTorch 버전: {torch.__version__}")
# Out:
# PyTorch 버전: 2.9.0+cpu
