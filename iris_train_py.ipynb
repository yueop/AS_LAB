# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/iris_train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil

# 1. 설정 파일 복사
print("IRIS 설정을 적용합니다...")
shutil.copy('config_iris.yaml', 'config.yaml')

# 2. train.py 실행 (느낌표 사용!)
print("IRIS 모델 학습 시작!")
# !python train.py

# 3. eval.py 실행 (느낌표 사용!)
print("IRIS 모델 평가 시작!")
# !python eval.py
# Out:
# IRIS 설정을 적용합니다...
# IRIS 모델 학습 시작!
# device: cpu | model: mlp
# 학습을 시작합니다...
# Epoch [1/150] Time: 0.19s | Train Loss: 0.9924 Train Acc: 0.6583 | Val Loss: 0.7794 Val Acc: 0.9333
# Loss decreased (inf --> 0.779420). 모델을 저장합니다...
# Epoch [2/150] Time: 0.02s | Train Loss: 0.6839 Train Acc: 0.7500 | Val Loss: 0.3987 Val Acc: 0.8667
# Loss decreased (0.779420 --> 0.398731). 모델을 저장합니다...
# Epoch [3/150] Time: 0.01s | Train Loss: 0.4362 Train Acc: 0.8167 | Val Loss: 0.2513 Val Acc: 1.0000
# Loss decreased (0.398731 --> 0.251253). 모델을 저장합니다...
# Epoch [4/150] Time: 0.01s | Train Loss: 0.3184 Train Acc: 0.9000 | Val Loss: 0.1850 Val Acc: 1.0000
# Loss decreased (0.251253 --> 0.185035). 모델을 저장합니다...
# Epoch [5/150] Time: 0.02s | Train Loss: 0.2536 Train Acc: 0.8917 | Val Loss: 0.1114 Val Acc: 1.0000
# Loss decreased (0.185035 --> 0.111409). 모델을 저장합니다...
# Epoch [6/150] Time: 0.01s | Train Loss: 0.2031 Train Acc: 0.9167 | Val Loss: 0.0951 Val Acc: 1.0000
# Loss decreased (0.111409 --> 0.095076). 모델을 저장합니다...
# Epoch [7/150] Time: 0.01s | Train Loss: 0.1672 Train Acc: 0.9500 | Val Loss: 0.0733 Val Acc: 1.0000
# Loss decreased (0.095076 --> 0.073329). 모델을 저장합니다...
# Epoch [8/150] Time: 0.01s | Train Loss: 0.1219 Train Acc: 0.9583 | Val Loss: 0.0570 Val Acc: 1.0000
# Loss decreased (0.073329 --> 0.057047). 모델을 저장합니다...
# Epoch [9/150] Time: 0.01s | Train Loss: 0.1149 Train Acc: 0.9583 | Val Loss: 0.0610 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch [10/150] Time: 0.01s | Train Loss: 0.1128 Train Acc: 0.9500 | Val Loss: 0.0357 Val Acc: 1.0000
# Loss decreased (0.057047 --> 0.035744). 모델을 저장합니다...
# Epoch [11/150] Time: 0.01s | Train Loss: 0.0822 Train Acc: 0.9667 | Val Loss: 0.0283 Val Acc: 1.0000
# Loss decreased (0.035744 --> 0.028323). 모델을 저장합니다...
# Epoch [12/150] Time: 0.01s | Train Loss: 0.0719 Train Acc: 0.9667 | Val Loss: 0.0345 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch [13/150] Time: 0.01s | Train Loss: 0.0652 Train Acc: 0.9667 | Val Loss: 0.0232 Val Acc: 1.0000
# Loss decreased (0.028323 --> 0.023215). 모델을 저장합니다...
# Epoch [14/150] Time: 0.02s | Train Loss: 0.0649 Train Acc: 0.9667 | Val Loss: 0.0227 Val Acc: 1.0000
# Loss decreased (0.023215 --> 0.022684). 모델을 저장합니다...
# Epoch [15/150] Time: 0.02s | Train Loss: 0.0659 Train Acc: 0.9667 | Val Loss: 0.0273 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch [16/150] Time: 0.01s | Train Loss: 0.0550 Train Acc: 0.9750 | Val Loss: 0.0194 Val Acc: 1.0000
# Loss decreased (0.022684 --> 0.019421). 모델을 저장합니다...
# Epoch [17/150] Time: 0.01s | Train Loss: 0.0671 Train Acc: 0.9667 | Val Loss: 0.0272 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch [18/150] Time: 0.01s | Train Loss: 0.0604 Train Acc: 0.9667 | Val Loss: 0.0236 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 10
# Epoch [19/150] Time: 0.01s | Train Loss: 0.0501 Train Acc: 0.9833 | Val Loss: 0.0476 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 10
# Epoch [20/150] Time: 0.01s | Train Loss: 0.0603 Train Acc: 0.9667 | Val Loss: 0.0208 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 10
# Epoch [21/150] Time: 0.01s | Train Loss: 0.0780 Train Acc: 0.9583 | Val Loss: 0.0382 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 10
# Epoch [22/150] Time: 0.01s | Train Loss: 0.0941 Train Acc: 0.9667 | Val Loss: 0.0120 Val Acc: 1.0000
# Loss decreased (0.019421 --> 0.012017). 모델을 저장합니다...
# Epoch [23/150] Time: 0.02s | Train Loss: 0.0492 Train Acc: 0.9750 | Val Loss: 0.0532 Val Acc: 1.0000
# EarlyStopping counter: 1 out of 10
# Epoch [24/150] Time: 0.02s | Train Loss: 0.0698 Train Acc: 0.9667 | Val Loss: 0.0181 Val Acc: 1.0000
# EarlyStopping counter: 2 out of 10
# Epoch [25/150] Time: 0.02s | Train Loss: 0.0461 Train Acc: 0.9833 | Val Loss: 0.0338 Val Acc: 1.0000
# EarlyStopping counter: 3 out of 10
# Epoch [26/150] Time: 0.01s | Train Loss: 0.0456 Train Acc: 0.9833 | Val Loss: 0.0261 Val Acc: 1.0000
# EarlyStopping counter: 4 out of 10
# Epoch [27/150] Time: 0.01s | Train Loss: 0.0439 Train Acc: 0.9750 | Val Loss: 0.0305 Val Acc: 1.0000
# EarlyStopping counter: 5 out of 10
# Epoch [28/150] Time: 0.01s | Train Loss: 0.0429 Train Acc: 0.9833 | Val Loss: 0.0228 Val Acc: 1.0000
# EarlyStopping counter: 6 out of 10
# Epoch [29/150] Time: 0.01s | Train Loss: 0.0523 Train Acc: 0.9750 | Val Loss: 0.0304 Val Acc: 1.0000
# EarlyStopping counter: 7 out of 10
# Epoch [30/150] Time: 0.01s | Train Loss: 0.0502 Train Acc: 0.9667 | Val Loss: 0.0158 Val Acc: 1.0000
# EarlyStopping counter: 8 out of 10
# Epoch [31/150] Time: 0.01s | Train Loss: 0.0393 Train Acc: 0.9833 | Val Loss: 0.0327 Val Acc: 1.0000
# EarlyStopping counter: 9 out of 10
# Epoch [32/150] Time: 0.01s | Train Loss: 0.0494 Train Acc: 0.9833 | Val Loss: 0.0178 Val Acc: 1.0000
# EarlyStopping counter: 10 out of 10
# Early Stopping이 작동되었습니다.
# 학습이 종료되었습니다.
# IRIS 모델 평가 시작!
# 평가 시작. Project: IRIS_Project
# 모델 가중치 로드 성공: best_iris.pth
# 최종 테스트 정확도: 93.33%
# Confusion Matrix 저장 완료: results/confusion_matrix.png
