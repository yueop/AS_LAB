# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/mnist_mlp_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil
import subprocess

# 실시간 출력을 강제로 화면에 뿌려주는 헬퍼 함수
def run_live_output(command):
    # 프로세스 실행 (stdout을 파이프로 연결)
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,  # 에러 메시지도 같이 출력
        text=True,                 # 텍스트 모드로 읽기
        bufsize=1                  # 라인 버퍼링
    )

    # 프로세스가 뱉는 로그를 한 줄씩 실시간으로 print
    for line in process.stdout:
        print(line, end='')

    # 프로세스 종료 대기 및 에러 체크
    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

# --- 메인 실행 로직 ---

# 1. 설정 파일 복사
print("=== [1] MNIST_MLP 설정을 적용합니다... ===")
shutil.copy('config_mnist_mlp.yaml', 'config.yaml')

# 2. train.py 실행
print("\n=== [2] 모델 학습 시작! ===")
run_live_output([sys.executable, "-u", "train.py"])

# 3. eval.py 실행
print("\n=== [3] 모델 평가 시작! ===")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# === [1] MNIST_MLP 설정을 적용합니다... ===
#
# === [2] 모델 학습 시작! ===
# device: cuda | model: mlp
# 학습을 시작합니다...
# Epoch [1/30] Time: 13.67s | Train Loss: 0.6617 Train Acc: 0.8307 | Val Loss: 0.3479 Val Acc: 0.8978
# Loss decreased (inf --> 0.347866). 모델을 저장합니다...
# Epoch [2/30] Time: 13.09s | Train Loss: 0.2961 Train Acc: 0.9140 | Val Loss: 0.2843 Val Acc: 0.9187
# Loss decreased (0.347866 --> 0.284254). 모델을 저장합니다...
# Epoch [3/30] Time: 13.14s | Train Loss: 0.2395 Train Acc: 0.9306 | Val Loss: 0.2318 Val Acc: 0.9343
# Loss decreased (0.284254 --> 0.231782). 모델을 저장합니다...
# Epoch [4/30] Time: 13.25s | Train Loss: 0.1988 Train Acc: 0.9418 | Val Loss: 0.2080 Val Acc: 0.9407
# Loss decreased (0.231782 --> 0.208001). 모델을 저장합니다...
# Epoch [5/30] Time: 12.95s | Train Loss: 0.1697 Train Acc: 0.9506 | Val Loss: 0.1808 Val Acc: 0.9483
# Loss decreased (0.208001 --> 0.180781). 모델을 저장합니다...
# Epoch [6/30] Time: 12.86s | Train Loss: 0.1474 Train Acc: 0.9570 | Val Loss: 0.1632 Val Acc: 0.9517
# Loss decreased (0.180781 --> 0.163186). 모델을 저장합니다...
# Epoch [7/30] Time: 13.02s | Train Loss: 0.1278 Train Acc: 0.9633 | Val Loss: 0.1620 Val Acc: 0.9517
# Loss decreased (0.163186 --> 0.162033). 모델을 저장합니다...
# Epoch [8/30] Time: 13.10s | Train Loss: 0.1132 Train Acc: 0.9671 | Val Loss: 0.1410 Val Acc: 0.9591
# Loss decreased (0.162033 --> 0.141030). 모델을 저장합니다...
# Epoch [9/30] Time: 13.21s | Train Loss: 0.1011 Train Acc: 0.9706 | Val Loss: 0.1385 Val Acc: 0.9577
# Loss decreased (0.141030 --> 0.138457). 모델을 저장합니다...
# Epoch [10/30] Time: 13.00s | Train Loss: 0.0908 Train Acc: 0.9741 | Val Loss: 0.1182 Val Acc: 0.9635
# Loss decreased (0.138457 --> 0.118245). 모델을 저장합니다...
# Epoch [11/30] Time: 13.03s | Train Loss: 0.0828 Train Acc: 0.9759 | Val Loss: 0.1135 Val Acc: 0.9661
# Loss decreased (0.118245 --> 0.113467). 모델을 저장합니다...
# Epoch [12/30] Time: 13.12s | Train Loss: 0.0743 Train Acc: 0.9784 | Val Loss: 0.1099 Val Acc: 0.9663
# Loss decreased (0.113467 --> 0.109907). 모델을 저장합니다...
# Epoch [13/30] Time: 13.01s | Train Loss: 0.0680 Train Acc: 0.9807 | Val Loss: 0.1037 Val Acc: 0.9689
# Loss decreased (0.109907 --> 0.103682). 모델을 저장합니다...
# Epoch [14/30] Time: 13.07s | Train Loss: 0.0619 Train Acc: 0.9819 | Val Loss: 0.0974 Val Acc: 0.9709
# Loss decreased (0.103682 --> 0.097389). 모델을 저장합니다...
# Epoch [15/30] Time: 12.87s | Train Loss: 0.0562 Train Acc: 0.9841 | Val Loss: 0.0943 Val Acc: 0.9711
# Loss decreased (0.097389 --> 0.094282). 모델을 저장합니다...
# Epoch [16/30] Time: 12.96s | Train Loss: 0.0511 Train Acc: 0.9852 | Val Loss: 0.0943 Val Acc: 0.9697
# EarlyStopping counter: 1 out of 3
# Epoch [17/30] Time: 13.01s | Train Loss: 0.0474 Train Acc: 0.9863 | Val Loss: 0.0931 Val Acc: 0.9714
# Loss decreased (0.094282 --> 0.093138). 모델을 저장합니다...
# Epoch [18/30] Time: 12.80s | Train Loss: 0.0435 Train Acc: 0.9875 | Val Loss: 0.0917 Val Acc: 0.9728
# Loss decreased (0.093138 --> 0.091652). 모델을 저장합니다...
# Epoch [19/30] Time: 13.03s | Train Loss: 0.0396 Train Acc: 0.9889 | Val Loss: 0.0892 Val Acc: 0.9723
# Loss decreased (0.091652 --> 0.089206). 모델을 저장합니다...
# Epoch [20/30] Time: 12.89s | Train Loss: 0.0368 Train Acc: 0.9896 | Val Loss: 0.0901 Val Acc: 0.9724
# EarlyStopping counter: 1 out of 3
# Epoch [21/30] Time: 12.99s | Train Loss: 0.0335 Train Acc: 0.9909 | Val Loss: 0.0889 Val Acc: 0.9726
# Loss decreased (0.089206 --> 0.088896). 모델을 저장합니다...
# Epoch [22/30] Time: 13.15s | Train Loss: 0.0309 Train Acc: 0.9914 | Val Loss: 0.0853 Val Acc: 0.9738
# Loss decreased (0.088896 --> 0.085281). 모델을 저장합니다...
# Epoch [23/30] Time: 12.98s | Train Loss: 0.0277 Train Acc: 0.9919 | Val Loss: 0.0866 Val Acc: 0.9734
# EarlyStopping counter: 1 out of 3
# Epoch [24/30] Time: 12.67s | Train Loss: 0.0255 Train Acc: 0.9935 | Val Loss: 0.0864 Val Acc: 0.9745
# EarlyStopping counter: 2 out of 3
# Epoch [25/30] Time: 12.73s | Train Loss: 0.0229 Train Acc: 0.9937 | Val Loss: 0.0861 Val Acc: 0.9741
# EarlyStopping counter: 3 out of 3
# Early Stopping이 작동되었습니다.
# 학습이 종료되었습니다. | 학습 시간: 325.5831594467163
# 학습 그래프가 저장되었습니다: /content/drive/MyDrive/AS_LAB/results/MNIST_MLP/learning_curve.png
#
# === [3] 모델 평가 시작! ===
# 평가 시작. Project: MNIST_MLP
# 모델 가중치 로드 성공: best_mnist_mlp.pth
# 최종 테스트 정확도: 97.77%
# Confusion Matrix 저장 완료: /content/drive/MyDrive/AS_LAB/results/MNIST_MLP/confusion_matrix.png
# 오분류 이미지 저장 완료: /content/drive/MyDrive/AS_LAB/results/MNIST_MLP/misclassified_sample.png
