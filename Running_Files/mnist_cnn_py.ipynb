# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/mnist_cnn_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil
import subprocess

def run_live_output(command):
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1
    )

    for line in process.stdout:
        print(line, end='')

    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

print("MNIST_CNN 설정 적용")
shutil.copy('config_mnist_cnn.yaml', 'config.yaml')

print("학습 시작")
run_live_output([sys.executable, "-u", "train.py"])

print("평가 시작")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# MNIST_CNN 설정 적용
# 학습 시작
# device: cuda | model: cnn
# 학습을 시작합니다...
# Epoch [1/30] Time: 15.19s | Train Loss: 0.1695 Train Acc: 0.9465 | Val Loss: 0.0948 Val Acc: 0.9710
# Loss decreased (inf --> 0.094830). 모델을 저장합니다...
# Epoch [2/30] Time: 14.25s | Train Loss: 0.0749 Train Acc: 0.9770 | Val Loss: 0.0861 Val Acc: 0.9738
# Loss decreased (0.094830 --> 0.086103). 모델을 저장합니다...
# Epoch [3/30] Time: 13.84s | Train Loss: 0.0646 Train Acc: 0.9801 | Val Loss: 0.0803 Val Acc: 0.9758
# Loss decreased (0.086103 --> 0.080273). 모델을 저장합니다...
# Epoch [4/30] Time: 13.39s | Train Loss: 0.0604 Train Acc: 0.9810 | Val Loss: 0.0652 Val Acc: 0.9822
# Loss decreased (0.080273 --> 0.065156). 모델을 저장합니다...
# Epoch [5/30] Time: 13.50s | Train Loss: 0.0569 Train Acc: 0.9820 | Val Loss: 0.0683 Val Acc: 0.9812
# EarlyStopping counter: 1 out of 3
# Epoch [6/30] Time: 13.46s | Train Loss: 0.0532 Train Acc: 0.9825 | Val Loss: 0.0845 Val Acc: 0.9765
# EarlyStopping counter: 2 out of 3
# Epoch [7/30] Time: 13.38s | Train Loss: 0.0520 Train Acc: 0.9841 | Val Loss: 0.0727 Val Acc: 0.9792
# EarlyStopping counter: 3 out of 3
# Early Stopping이 작동되었습니다.
# 학습이 종료되었습니다. | 학습 시간: 97.01491737365723
# 학습 그래프가 저장되었습니다: /content/drive/MyDrive/AS_LAB/results/MNIST_CNN/learning_curve.png
# 평가 시작
# 평가 시작. Project: MNIST_CNN
# 모델 가중치 로드 성공: best_mnist_cnn.pth
# 최종 테스트 정확도: 98.25%
# Confusion Matrix 저장 완료: /content/drive/MyDrive/AS_LAB/results/MNIST_CNN/confusion_matrix.png
# 오분류 이미지 저장 완료: /content/drive/MyDrive/AS_LAB/results/MNIST_CNN/misclassified_sample.png
