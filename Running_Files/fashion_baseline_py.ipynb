# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/fashion_baseline_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil
import subprocess

def run_live_output(command):
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1
    )

    for line in process.stdout:
        print(line, end='')

    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

print("FASHION_BASELINE 설정 적용")
shutil.copy('config_fashion_baseline.yaml', 'config.yaml')

print("학습 시작")
run_live_output([sys.executable, "-u", "train.py"])

print("평가 시작")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# FASHION_BASELINE 설정 적용
# 학습 시작
# device: cuda | model: cnn
# Scheduler Activated: StepLR (step=10, gamma=0.1)
# 학습을 시작합니다...
# Epoch [1/50] Time: 13.41s | Train Loss: 0.5797 Train Acc: 0.7966 | Val Loss: 0.4349 Val Acc: 0.8445
# Loss decreased (inf --> 0.434850). 모델을 저장합니다...
# Epoch [2/50] Time: 13.16s | Train Loss: 0.3794 Train Acc: 0.8658 | Val Loss: 0.3570 Val Acc: 0.8752
# Loss decreased (0.434850 --> 0.356993). 모델을 저장합니다...
# Epoch [3/50] Time: 13.21s | Train Loss: 0.3362 Train Acc: 0.8804 | Val Loss: 0.3381 Val Acc: 0.8788
# Loss decreased (0.356993 --> 0.338148). 모델을 저장합니다...
# Epoch [4/50] Time: 13.10s | Train Loss: 0.3067 Train Acc: 0.8905 | Val Loss: 0.3211 Val Acc: 0.8862
# Loss decreased (0.338148 --> 0.321149). 모델을 저장합니다...
# Epoch [5/50] Time: 12.96s | Train Loss: 0.2883 Train Acc: 0.8967 | Val Loss: 0.3216 Val Acc: 0.8849
# EarlyStopping counter: 1 out of 5
# Epoch [6/50] Time: 12.96s | Train Loss: 0.2714 Train Acc: 0.9021 | Val Loss: 0.2910 Val Acc: 0.8970
# ...
