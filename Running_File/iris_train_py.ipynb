# %% [markdown]
# <a href="https://colab.research.google.com/github/yueop/AS_LAB/blob/main/iris_train_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from google.colab import drive

# 1. 드라이브 마운트
drive.mount('/content/drive')

# 2. 경로 설정
PROJECT_PATH = '/content/drive/MyDrive/AS_LAB'
if not os.path.exists(PROJECT_PATH):
    os.makedirs(PROJECT_PATH)

# 3. 시스템 경로 추가 및 작업 디렉토리 변경
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
os.chdir(PROJECT_PATH)

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/AS_LAB

# %%
import shutil
import subprocess
import os
import sys

# 실시간 출력을 강제로 화면에 뿌려주는 헬퍼 함수
def run_live_output(command):
    # 프로세스 실행 (stdout을 파이프로 연결)
    process = subprocess.Popen(
        command,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,  # 에러 메시지도 같이 출력
        text=True,                 # 텍스트 모드로 읽기
        bufsize=1                  # 라인 버퍼링
    )

    # 프로세스가 뱉는 로그를 한 줄씩 실시간으로 print
    for line in process.stdout:
        print(line, end='')

    # 프로세스 종료 대기 및 에러 체크
    process.wait()
    if process.returncode != 0:
        raise subprocess.CalledProcessError(process.returncode, command)

# --- 메인 실행 로직 ---

# 1. 설정 파일 복사
print("=== [1] IRIS 설정을 적용합니다... ===")
shutil.copy('config_iris.yaml', 'config.yaml')

# 2. train.py 실행
print("\n=== [2] IRIS 모델 학습 시작! ===")
run_live_output([sys.executable, "-u", "train.py"])

# 3. eval.py 실행
print("\n=== [3] IRIS 모델 평가 시작! ===")
run_live_output([sys.executable, "-u", "eval.py"])
# Out:
# === [1] IRIS 설정을 적용합니다... ===
#
# === [2] IRIS 모델 학습 시작! ===
# device: cpu | model: mlp
# ---[디버깅] Seed 42 | 첫 번재 학습 데이터: [0.61775825 0.78219968 1.04811307 1.59858957]---
# 학습을 시작합니다...
# Epoch [1/100] Time: 0.04s | Train Loss: 1.0879 Train Acc: 0.3146 | Val Loss: 1.0410 Val Acc: 0.5217
# Loss decreased (inf --> 1.040976). 모델을 저장합니다...
# Epoch [2/100] Time: 0.01s | Train Loss: 1.0736 Train Acc: 0.3483 | Val Loss: 1.0321 Val Acc: 0.5217
# Loss decreased (1.040976 --> 1.032062). 모델을 저장합니다...
# Epoch [3/100] Time: 0.01s | Train Loss: 1.0569 Train Acc: 0.4719 | Val Loss: 1.0231 Val Acc: 0.6957
# Loss decreased (1.032062 --> 1.023082). 모델을 저장합니다...
# Epoch [4/100] Time: 0.01s | Train Loss: 1.0397 Train Acc: 0.6742 | Val Loss: 1.0137 Val Acc: 0.8261
# Loss decreased (1.023082 --> 1.013704). 모델을 저장합니다...
# Epoch [5/100] Time: 0.01s | Train Loss: 1.0208 Train Acc: 0.8202 | Val Loss: 1.0033 Val Acc: 0.7826
# Loss decreased (1.013704 --> 1.003333). 모델을 저장합니다...
# Epoch [6/100] Time: 0.01s | Train Loss: 1.0017 Train Acc: 0.9101 | Val Loss: 0.9907 Val Acc: 0.8261
# Loss decreased (1.003333 --> 0.990680). 모델을 저장합니다...
# Epoch [7/100] Time: 0.01s | Train Loss: 0.9782 Train Acc: 0.8989 | Val Loss: 0.9765 Val Acc: 0.7826
# Loss decreased (0.990680 --> 0.976479). 모델을 저장합니다...
# Epoch [8/100] Time: 0.01s | Train Loss: 0.9541 Train Acc: 0.8764 | Val Loss: 0.9604 Val Acc: 0.6957
# Loss decreased (0.976479 --> 0.960412). 모델을 저장합니다...
# Epoch [9/100] Time: 0.01s | Train Loss: 0.9267 Train Acc: 0.8652 | Val Loss: 0.9430 Val Acc: 0.6957
# Loss decreased (0.960412 --> 0.942996). 모델을 저장합니다...
# Epoch [10/100] Time: 0.01s | Train Loss: 0.9045 Train Acc: 0.8315 | Val Loss: 0.9254 Val Acc: 0.6957
# Loss decreased (0.942996 --> 0.925420). 모델을 저장합니다...
# Epoch [11/100] Time: 0.01s | Train Loss: 0.8717 Train Acc: 0.8315 | Val Loss: 0.9060 Val Acc: 0.6957
# Loss decreased (0.925420 --> 0.906028). 모델을 저장합니다...
# Epoch [12/100] Time: 0.01s | Train Loss: 0.8345 Train Acc: 0.8202 | Val Loss: 0.8855 Val Acc: 0.6522
# Loss decreased (0.906028 --> 0.885450). 모델을 저장합니다...
# Epoch [13/100] Time: 0.01s | Train Loss: 0.7990 Train Acc: 0.7978 | Val Loss: 0.8651 Val Acc: 0.6522
# Loss decreased (0.885450 --> 0.865111). 모델을 저장합니다...
# Epoch [14/100] Time: 0.01s | Train Loss: 0.7609 Train Acc: 0.7978 | Val Loss: 0.8446 Val Acc: 0.6522
# Loss decreased (0.865111 --> 0.844601). 모델을 저장합니다...
# Epoch [15/100] Time: 0.01s | Train Loss: 0.7329 Train Acc: 0.7640 | Val Loss: 0.8254 Val Acc: 0.6087
# Loss decreased (0.844601 --> 0.825358). 모델을 저장합니다...
# Epoch [16/100] Time: 0.01s | Train Loss: 0.6945 Train Acc: 0.7753 | Val Loss: 0.8054 Val Acc: 0.6087
# Loss decreased (0.825358 --> 0.805450). 모델을 저장합니다...
# Epoch [17/100] Time: 0.01s | Train Loss: 0.6674 Train Acc: 0.7753 | Val Loss: 0.7870 Val Acc: 0.6087
# Loss decreased (0.805450 --> 0.786971). 모델을 저장합니다...
# Epoch [18/100] Time: 0.01s | Train Loss: 0.6306 Train Acc: 0.7753 | Val Loss: 0.7691 Val Acc: 0.6087
# Loss decreased (0.786971 --> 0.769065). 모델을 저장합니다...
# Epoch [19/100] Time: 0.01s | Train Loss: 0.5929 Train Acc: 0.7753 | Val Loss: 0.7502 Val Acc: 0.6087
# Loss decreased (0.769065 --> 0.750200). 모델을 저장합니다...
# Epoch [20/100] Time: 0.01s | Train Loss: 0.5678 Train Acc: 0.7753 | Val Loss: 0.7341 Val Acc: 0.6522
# Loss decreased (0.750200 --> 0.734138). 모델을 저장합니다...
# Epoch [21/100] Time: 0.01s | Train Loss: 0.5590 Train Acc: 0.7865 | Val Loss: 0.7165 Val Acc: 0.6522
# Loss decreased (0.734138 --> 0.716515). 모델을 저장합니다...
# Epoch [22/100] Time: 0.01s | Train Loss: 0.5242 Train Acc: 0.7978 | Val Loss: 0.6967 Val Acc: 0.6522
# Loss decreased (0.716515 --> 0.696737). 모델을 저장합니다...
# Epoch [23/100] Time: 0.01s | Train Loss: 0.5140 Train Acc: 0.8315 | Val Loss: 0.6764 Val Acc: 0.6957
# Loss decreased (0.696737 --> 0.676356). 모델을 저장합니다...
# Epoch [24/100] Time: 0.01s | Train Loss: 0.4685 Train Acc: 0.8315 | Val Loss: 0.6566 Val Acc: 0.6957
# Loss decreased (0.676356 --> 0.656579). 모델을 저장합니다...
# Epoch [25/100] Time: 0.01s | Train Loss: 0.4643 Train Acc: 0.8427 | Val Loss: 0.6419 Val Acc: 0.7391
# Loss decreased (0.656579 --> 0.641878). 모델을 저장합니다...
# Epoch [26/100] Time: 0.01s | Train Loss: 0.4546 Train Acc: 0.8427 | Val Loss: 0.6248 Val Acc: 0.7391
# Loss decreased (0.641878 --> 0.624791). 모델을 저장합니다...
# Epoch [27/100] Time: 0.01s | Train Loss: 0.4293 Train Acc: 0.8539 | Val Loss: 0.6090 Val Acc: 0.7391
# Loss decreased (0.624791 --> 0.608989). 모델을 저장합니다...
# Epoch [28/100] Time: 0.01s | Train Loss: 0.4328 Train Acc: 0.8652 | Val Loss: 0.5938 Val Acc: 0.7391
# Loss decreased (0.608989 --> 0.593848). 모델을 저장합니다...
# Epoch [29/100] Time: 0.01s | Train Loss: 0.4210 Train Acc: 0.8652 | Val Loss: 0.5732 Val Acc: 0.7391
# Loss decreased (0.593848 --> 0.573150). 모델을 저장합니다...
# Epoch [30/100] Time: 0.01s | Train Loss: 0.3966 Train Acc: 0.8652 | Val Loss: 0.5560 Val Acc: 0.7391
# Loss decreased (0.573150 --> 0.556029). 모델을 저장합니다...
# Epoch [31/100] Time: 0.01s | Train Loss: 0.3787 Train Acc: 0.8764 | Val Loss: 0.5370 Val Acc: 0.7826
# Loss decreased (0.556029 --> 0.537014). 모델을 저장합니다...
# Epoch [32/100] Time: 0.01s | Train Loss: 0.3735 Train Acc: 0.8764 | Val Loss: 0.5187 Val Acc: 0.7826
# Loss decreased (0.537014 --> 0.518743). 모델을 저장합니다...
# Epoch [33/100] Time: 0.01s | Train Loss: 0.3562 Train Acc: 0.8764 | Val Loss: 0.5000 Val Acc: 0.7826
# Loss decreased (0.518743 --> 0.500012). 모델을 저장합니다...
# Epoch [34/100] Time: 0.01s | Train Loss: 0.3463 Train Acc: 0.8764 | Val Loss: 0.4850 Val Acc: 0.7826
# Loss decreased (0.500012 --> 0.484984). 모델을 저장합니다...
# Epoch [35/100] Time: 0.01s | Train Loss: 0.3512 Train Acc: 0.8989 | Val Loss: 0.4698 Val Acc: 0.7826
# Loss decreased (0.484984 --> 0.469794). 모델을 저장합니다...
# Epoch [36/100] Time: 0.01s | Train Loss: 0.3259 Train Acc: 0.8989 | Val Loss: 0.4532 Val Acc: 0.8261
# Loss decreased (0.469794 --> 0.453231). 모델을 저장합니다...
# Epoch [37/100] Time: 0.02s | Train Loss: 0.3295 Train Acc: 0.9101 | Val Loss: 0.4400 Val Acc: 0.8261
# Loss decreased (0.453231 --> 0.440032). 모델을 저장합니다...
# Epoch [38/100] Time: 0.02s | Train Loss: 0.3154 Train Acc: 0.9101 | Val Loss: 0.4238 Val Acc: 0.8261
# Loss decreased (0.440032 --> 0.423784). 모델을 저장합니다...
# Epoch [39/100] Time: 0.01s | Train Loss: 0.3052 Train Acc: 0.9101 | Val Loss: 0.4090 Val Acc: 0.8261
# Loss decreased (0.423784 --> 0.409037). 모델을 저장합니다...
# Epoch [40/100] Time: 0.01s | Train Loss: 0.2911 Train Acc: 0.9101 | Val Loss: 0.3933 Val Acc: 0.8261
# Loss decreased (0.409037 --> 0.393350). 모델을 저장합니다...
# Epoch [41/100] Time: 0.01s | Train Loss: 0.2886 Train Acc: 0.8989 | Val Loss: 0.3782 Val Acc: 0.8261
# Loss decreased (0.393350 --> 0.378246). 모델을 저장합니다...
# Epoch [42/100] Time: 0.01s | Train Loss: 0.2727 Train Acc: 0.8989 | Val Loss: 0.3696 Val Acc: 0.8261
# Loss decreased (0.378246 --> 0.369559). 모델을 저장합니다...
# Epoch [43/100] Time: 0.01s | Train Loss: 0.2753 Train Acc: 0.8989 | Val Loss: 0.3577 Val Acc: 0.8261
# Loss decreased (0.369559 --> 0.357736). 모델을 저장합니다...
# Epoch [44/100] Time: 0.01s | Train Loss: 0.2765 Train Acc: 0.8989 | Val Loss: 0.3493 Val Acc: 0.8261
# Loss decreased (0.357736 --> 0.349272). 모델을 저장합니다...
# Epoch [45/100] Time: 0.01s | Train Loss: 0.2513 Train Acc: 0.9101 | Val Loss: 0.3360 Val Acc: 0.8261
# Loss decreased (0.349272 --> 0.336016). 모델을 저장합니다...
# Epoch [46/100] Time: 0.01s | Train Loss: 0.2649 Train Acc: 0.9101 | Val Loss: 0.3225 Val Acc: 0.8261
# Loss decreased (0.336016 --> 0.322484). 모델을 저장합니다...
# Epoch [47/100] Time: 0.01s | Train Loss: 0.2440 Train Acc: 0.9213 | Val Loss: 0.3114 Val Acc: 0.8696
# Loss decreased (0.322484 --> 0.311385). 모델을 저장합니다...
# Epoch [48/100] Time: 0.01s | Train Loss: 0.2360 Train Acc: 0.9213 | Val Loss: 0.3028 Val Acc: 0.8696
# Loss decreased (0.311385 --> 0.302780). 모델을 저장합니다...
# Epoch [49/100] Time: 0.01s | Train Loss: 0.2325 Train Acc: 0.9213 | Val Loss: 0.2978 Val Acc: 0.8696
# Loss decreased (0.302780 --> 0.297836). 모델을 저장합니다...
# Epoch [50/100] Time: 0.01s | Train Loss: 0.2314 Train Acc: 0.9213 | Val Loss: 0.2901 Val Acc: 0.8696
# Loss decreased (0.297836 --> 0.290120). 모델을 저장합니다...
# Epoch [51/100] Time: 0.01s | Train Loss: 0.2369 Train Acc: 0.9213 | Val Loss: 0.2807 Val Acc: 0.8696
# Loss decreased (0.290120 --> 0.280712). 모델을 저장합니다...
# Epoch [52/100] Time: 0.01s | Train Loss: 0.2212 Train Acc: 0.9213 | Val Loss: 0.2758 Val Acc: 0.8696
# Loss decreased (0.280712 --> 0.275817). 모델을 저장합니다...
# Epoch [53/100] Time: 0.01s | Train Loss: 0.2090 Train Acc: 0.9326 | Val Loss: 0.2656 Val Acc: 0.8696
# Loss decreased (0.275817 --> 0.265555). 모델을 저장합니다...
# Epoch [54/100] Time: 0.01s | Train Loss: 0.2193 Train Acc: 0.9213 | Val Loss: 0.2563 Val Acc: 0.8696
# Loss decreased (0.265555 --> 0.256292). 모델을 저장합니다...
# Epoch [55/100] Time: 0.01s | Train Loss: 0.2073 Train Acc: 0.9326 | Val Loss: 0.2471 Val Acc: 0.8696
# Loss decreased (0.256292 --> 0.247102). 모델을 저장합니다...
# Epoch [56/100] Time: 0.01s | Train Loss: 0.1984 Train Acc: 0.9326 | Val Loss: 0.2411 Val Acc: 0.8696
# Loss decreased (0.247102 --> 0.241119). 모델을 저장합니다...
# Epoch [57/100] Time: 0.01s | Train Loss: 0.2047 Train Acc: 0.9326 | Val Loss: 0.2365 Val Acc: 0.8696
# Loss decreased (0.241119 --> 0.236462). 모델을 저장합니다...
# Epoch [58/100] Time: 0.01s | Train Loss: 0.2043 Train Acc: 0.9326 | Val Loss: 0.2276 Val Acc: 0.8696
# Loss decreased (0.236462 --> 0.227645). 모델을 저장합니다...
# Epoch [59/100] Time: 0.01s | Train Loss: 0.1781 Train Acc: 0.9438 | Val Loss: 0.2128 Val Acc: 0.8696
# Loss decreased (0.227645 --> 0.212797). 모델을 저장합니다...
# Epoch [60/100] Time: 0.01s | Train Loss: 0.1908 Train Acc: 0.9438 | Val Loss: 0.2040 Val Acc: 0.9130
# Loss decreased (0.212797 --> 0.203967). 모델을 저장합니다...
# Epoch [61/100] Time: 0.01s | Train Loss: 0.1702 Train Acc: 0.9438 | Val Loss: 0.1978 Val Acc: 0.9130
# Loss decreased (0.203967 --> 0.197778). 모델을 저장합니다...
# Epoch [62/100] Time: 0.01s | Train Loss: 0.1664 Train Acc: 0.9551 | Val Loss: 0.1937 Val Acc: 0.9130
# Loss decreased (0.197778 --> 0.193725). 모델을 저장합니다...
# Epoch [63/100] Time: 0.01s | Train Loss: 0.1707 Train Acc: 0.9551 | Val Loss: 0.1896 Val Acc: 0.9130
# Loss decreased (0.193725 --> 0.189577). 모델을 저장합니다...
# Epoch [64/100] Time: 0.01s | Train Loss: 0.1629 Train Acc: 0.9551 | Val Loss: 0.1844 Val Acc: 0.9130
# Loss decreased (0.189577 --> 0.184352). 모델을 저장합니다...
# Epoch [65/100] Time: 0.01s | Train Loss: 0.1551 Train Acc: 0.9551 | Val Loss: 0.1794 Val Acc: 0.9130
# Loss decreased (0.184352 --> 0.179354). 모델을 저장합니다...
# Epoch [66/100] Time: 0.01s | Train Loss: 0.1602 Train Acc: 0.9551 | Val Loss: 0.1733 Val Acc: 0.9130
# Loss decreased (0.179354 --> 0.173284). 모델을 저장합니다...
# Epoch [67/100] Time: 0.01s | Train Loss: 0.1641 Train Acc: 0.9551 | Val Loss: 0.1694 Val Acc: 0.9130
# Loss decreased (0.173284 --> 0.169388). 모델을 저장합니다...
# Epoch [68/100] Time: 0.01s | Train Loss: 0.1523 Train Acc: 0.9551 | Val Loss: 0.1682 Val Acc: 0.9130
# Loss decreased (0.169388 --> 0.168169). 모델을 저장합니다...
# Epoch [69/100] Time: 0.01s | Train Loss: 0.1416 Train Acc: 0.9551 | Val Loss: 0.1632 Val Acc: 0.9130
# Loss decreased (0.168169 --> 0.163186). 모델을 저장합니다...
# Epoch [70/100] Time: 0.01s | Train Loss: 0.1493 Train Acc: 0.9551 | Val Loss: 0.1557 Val Acc: 0.9565
# Loss decreased (0.163186 --> 0.155699). 모델을 저장합니다...
# Epoch [71/100] Time: 0.01s | Train Loss: 0.1387 Train Acc: 0.9551 | Val Loss: 0.1520 Val Acc: 0.9565
# Loss decreased (0.155699 --> 0.151999). 모델을 저장합니다...
# Epoch [72/100] Time: 0.01s | Train Loss: 0.1358 Train Acc: 0.9551 | Val Loss: 0.1464 Val Acc: 0.9565
# Loss decreased (0.151999 --> 0.146393). 모델을 저장합니다...
# Epoch [73/100] Time: 0.01s | Train Loss: 0.1313 Train Acc: 0.9551 | Val Loss: 0.1419 Val Acc: 0.9565
# Loss decreased (0.146393 --> 0.141886). 모델을 저장합니다...
# Epoch [74/100] Time: 0.01s | Train Loss: 0.1304 Train Acc: 0.9551 | Val Loss: 0.1372 Val Acc: 0.9565
# Loss decreased (0.141886 --> 0.137235). 모델을 저장합니다...
# Epoch [75/100] Time: 0.01s | Train Loss: 0.1237 Train Acc: 0.9551 | Val Loss: 0.1348 Val Acc: 0.9565
# Loss decreased (0.137235 --> 0.134798). 모델을 저장합니다...
# Epoch [76/100] Time: 0.01s | Train Loss: 0.1317 Train Acc: 0.9551 | Val Loss: 0.1324 Val Acc: 0.9565
# Loss decreased (0.134798 --> 0.132378). 모델을 저장합니다...
# Epoch [77/100] Time: 0.01s | Train Loss: 0.1214 Train Acc: 0.9551 | Val Loss: 0.1276 Val Acc: 0.9565
# Loss decreased (0.132378 --> 0.127633). 모델을 저장합니다...
# Epoch [78/100] Time: 0.01s | Train Loss: 0.1316 Train Acc: 0.9551 | Val Loss: 0.1257 Val Acc: 0.9565
# Loss decreased (0.127633 --> 0.125673). 모델을 저장합니다...
# Epoch [79/100] Time: 0.01s | Train Loss: 0.1237 Train Acc: 0.9551 | Val Loss: 0.1194 Val Acc: 0.9565
# Loss decreased (0.125673 --> 0.119374). 모델을 저장합니다...
# Epoch [80/100] Time: 0.01s | Train Loss: 0.1120 Train Acc: 0.9551 | Val Loss: 0.1144 Val Acc: 0.9565
# Loss decreased (0.119374 --> 0.114444). 모델을 저장합니다...
# Epoch [81/100] Time: 0.01s | Train Loss: 0.1111 Train Acc: 0.9663 | Val Loss: 0.1104 Val Acc: 0.9565
# Loss decreased (0.114444 --> 0.110393). 모델을 저장합니다...
# Epoch [82/100] Time: 0.01s | Train Loss: 0.1164 Train Acc: 0.9663 | Val Loss: 0.1089 Val Acc: 0.9565
# Loss decreased (0.110393 --> 0.108893). 모델을 저장합니다...
# Epoch [83/100] Time: 0.02s | Train Loss: 0.1164 Train Acc: 0.9663 | Val Loss: 0.1059 Val Acc: 0.9565
# Loss decreased (0.108893 --> 0.105909). 모델을 저장합니다...
# Epoch [84/100] Time: 0.02s | Train Loss: 0.1085 Train Acc: 0.9663 | Val Loss: 0.1050 Val Acc: 0.9565
# Loss decreased (0.105909 --> 0.105012). 모델을 저장합니다...
# Epoch [85/100] Time: 0.02s | Train Loss: 0.1139 Train Acc: 0.9663 | Val Loss: 0.1041 Val Acc: 0.9565
# Loss decreased (0.105012 --> 0.104074). 모델을 저장합니다...
# Epoch [86/100] Time: 0.01s | Train Loss: 0.1062 Train Acc: 0.9663 | Val Loss: 0.1017 Val Acc: 0.9565
# Loss decreased (0.104074 --> 0.101684). 모델을 저장합니다...
# Epoch [87/100] Time: 0.01s | Train Loss: 0.1029 Train Acc: 0.9663 | Val Loss: 0.0968 Val Acc: 0.9565
# Loss decreased (0.101684 --> 0.096834). 모델을 저장합니다...
# Epoch [88/100] Time: 0.01s | Train Loss: 0.1186 Train Acc: 0.9551 | Val Loss: 0.0946 Val Acc: 0.9565
# Loss decreased (0.096834 --> 0.094621). 모델을 저장합니다...
# Epoch [89/100] Time: 0.01s | Train Loss: 0.1124 Train Acc: 0.9551 | Val Loss: 0.0934 Val Acc: 0.9565
# Loss decreased (0.094621 --> 0.093367). 모델을 저장합니다...
# Epoch [90/100] Time: 0.01s | Train Loss: 0.1025 Train Acc: 0.9551 | Val Loss: 0.0907 Val Acc: 0.9565
# Loss decreased (0.093367 --> 0.090728). 모델을 저장합니다...
# Epoch [91/100] Time: 0.01s | Train Loss: 0.1092 Train Acc: 0.9663 | Val Loss: 0.0911 Val Acc: 0.9565
# EarlyStopping counter: 1 out of 10
# Epoch [92/100] Time: 0.01s | Train Loss: 0.0957 Train Acc: 0.9775 | Val Loss: 0.0904 Val Acc: 0.9565
# Loss decreased (0.090728 --> 0.090376). 모델을 저장합니다...
# Epoch [93/100] Time: 0.01s | Train Loss: 0.0965 Train Acc: 0.9775 | Val Loss: 0.0889 Val Acc: 0.9565
# Loss decreased (0.090376 --> 0.088940). 모델을 저장합니다...
# Epoch [94/100] Time: 0.01s | Train Loss: 0.0954 Train Acc: 0.9775 | Val Loss: 0.0880 Val Acc: 0.9565
# Loss decreased (0.088940 --> 0.087958). 모델을 저장합니다...
# Epoch [95/100] Time: 0.01s | Train Loss: 0.0944 Train Acc: 0.9775 | Val Loss: 0.0869 Val Acc: 0.9565
# Loss decreased (0.087958 --> 0.086905). 모델을 저장합니다...
# Epoch [96/100] Time: 0.01s | Train Loss: 0.0949 Train Acc: 0.9775 | Val Loss: 0.0861 Val Acc: 0.9565
# Loss decreased (0.086905 --> 0.086117). 모델을 저장합니다...
# Epoch [97/100] Time: 0.01s | Train Loss: 0.0942 Train Acc: 0.9775 | Val Loss: 0.0844 Val Acc: 0.9565
# Loss decreased (0.086117 --> 0.084393). 모델을 저장합니다...
# Epoch [98/100] Time: 0.01s | Train Loss: 0.0986 Train Acc: 0.9775 | Val Loss: 0.0828 Val Acc: 0.9565
# Loss decreased (0.084393 --> 0.082791). 모델을 저장합니다...
# Epoch [99/100] Time: 0.01s | Train Loss: 0.0855 Train Acc: 0.9775 | Val Loss: 0.0801 Val Acc: 0.9565
# Loss decreased (0.082791 --> 0.080070). 모델을 저장합니다...
# Epoch [100/100] Time: 0.01s | Train Loss: 0.0850 Train Acc: 0.9663 | Val Loss: 0.0785 Val Acc: 0.9565
# Loss decreased (0.080070 --> 0.078484). 모델을 저장합니다...
# 학습이 종료되었습니다.
# 학습 그래프가 저장되었습니다: /content/drive/MyDrive/AS_LAB/results/IRIS_Project/learning_curve.png
#
# === [3] IRIS 모델 평가 시작! ===
# 평가 시작. Project: IRIS_Project
# 모델 가중치 로드 성공: best_iris.pth
# 최종 테스트 정확도: 97.37%
# Confusion Matrix 저장 완료: /content/drive/MyDrive/AS_LAB/results/IRIS_Project/confusion_matrix.png
